# %% [markdown]
# This notebook will go through my process for messing around with clustering using the DBSCAN algorithm

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN

# %%
raw_data = pd.read_csv('dataset.csv')
print(raw_data.head())
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.680   0.729    7    -5.097       0.0418        0.3670
# 1         0.584   0.607   11    -6.605       0.0356        0.4260
# 2         0.703   0.643    7    -5.544       0.0706        0.1920
# 3         0.746   0.450    7    -8.543       0.0872        0.0407
# 4         0.561   0.597   11    -6.000       0.0405        0.2860
#
#    instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.0    0.1590    0.830  120.029               4
# 1               0.0    0.1010    0.374  117.817               4
# 2               0.0    0.1430    0.528  102.059               4
# 3               0.0    0.1720    0.336   95.998               4
# 4               0.0    0.0979    0.355   76.826               4
#
#                  song_uri                     name  mode_major  mode_minor
# 0  3TMUdD9vE4DoqDYi7VXStt              Fool's Gold           1           0
# 1  3TKpJrY9q49Mj1JOsM9zGL                   Family           1           0
# 2  0CJvDUBeEL1Rmpx7MH28CQ                  For You           1           0
# 3  3GRSqlALWISqLeNncZMbpX                  Mean It           1           0
# 4  1yTTMcUhL7rtz08Dsgb7Qb  The Bones - with Hozier           0           1

# %%
raw_data = raw_data.astype({'key': 'float64', 'time_signature':'float64'}, copy=True)
prep_data = raw_data.copy()
prep_data = prep_data.drop(columns=['song_uri', 'name'])

print(prep_data.shape)
print(prep_data.head())
algo_data = prep_data.to_numpy()
# Out:
# (2156, 13)
#    danceability  energy   key  loudness  speechiness  acousticness  \
# 0         0.680   0.729   7.0    -5.097       0.0418        0.3670
# 1         0.584   0.607  11.0    -6.605       0.0356        0.4260
# 2         0.703   0.643   7.0    -5.544       0.0706        0.1920
# 3         0.746   0.450   7.0    -8.543       0.0872        0.0407
# 4         0.561   0.597  11.0    -6.000       0.0405        0.2860
#
#    instrumentalness  liveness  valence    tempo  time_signature  mode_major  \
# 0               0.0    0.1590    0.830  120.029             4.0           1
# 1               0.0    0.1010    0.374  117.817             4.0           1
# 2               0.0    0.1430    0.528  102.059             4.0           1
# 3               0.0    0.1720    0.336   95.998             4.0           1
# 4               0.0    0.0979    0.355   76.826             4.0           0
#
#    mode_minor
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1

# %% [markdown]
# So the two parameters for DBSCAN are the Minimum # of Points in a neighborhood, and the Maximum Distance between two points in the same neighborhood.<br>
# Since our clusters represent playlists, the smallest number of points we would want in a playlist might be 10, as that would give us a 30 minute playlist.<br>
# To find some realistic values for distances, let's do some quick analysis. We have 13 total features.
# 2 of the features have a minimum of 0 and a maximum of 1. If we assume that the other 11 features have a minimum of -8 and a maximum of 8, then the vector representing the furthest possible distance would be have 11 distances of 16 and 2 distances of 1. The length of this vector is as follows

# %%
min_feature_values = np.min(prep_data)
max_feature_values = np.max(prep_data)
distance = max_feature_values - min_feature_values
print('\nMax possible distance: {}'.format(np.linalg.norm(distance.values)))
# Out:
# Max possible distance: 162.51068223535762

# %% [markdown]
# So, an absolute maximum distance in our transformed feature space is about 162.<br>
# As epsilon rises, there will be less noise, as more points will be reachable by others.<br>
# It is important to note that as min_samples rises, there will be fewer clusters

# %%
algo = DBSCAN(eps=2, min_samples=5).fit(algo_data)
labels = algo.labels_
clusters = set(labels)

total_songs = len(labels)
num_noise = sum(labels==-1)
print('Percent Noise: {:.2f}'.format(100*num_noise/total_songs))
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print('Number of clusters: {}'.format(n_clusters_))

playlist_clusters = []
for cluster_num, ndx in enumerate(clusters):
    if (ndx == -1):
        print('\nNoise Cluster')
    else:    
        num_points = sum(labels == ndx)
        if (num_points > 10):
            print('\nCluster {}'.format(cluster_num + 1))
            print('Number of Points: {}'.format(num_points))
            cluster = raw_data.iloc[(labels == ndx), :]
            print('Cluster Songs:\n{}'.format(cluster.name))
            playlist_clusters.append(ndx)
# Out:
# Percent Noise: 30.94
# Number of clusters: 44
#
# Cluster 1
# Number of Points: 83
# Cluster Songs:
# 0                                       Fool's Gold
# 32                  I Wanna Know (feat. Bea Miller)
# 67                                     Cold Showers
# 122                                      heavy snow
# 134                                 Ungrateful Eyes
#                            ...
# 2144                       Say My Name (feat. Zyra)
# 2147                         It’s Only (feat. Zyra)
# 2148    Memories That You Call (feat. Monsoonsiren)
# 2151                                        Sundara
# 2155               Sun Models (feat. Madelyn Grant)
# Name: name, Length: 83, dtype: object
#
# Cluster 2
# Number of Points: 351
# Cluster Songs:
# 2                             For You
# 3                             Mean It
# 19                            Houdini
# 26                  You Are Losing Me
# 31                           Memories
#                     ...
# 2136                             Kids
# 2140                I. The Worst Guys
# 2149     For Us (feat. Briana Marela)
# 2150    All We Need (feat. Shy Girls)
# 2154                             Koto
# Name: name, Length: 351, dtype: object
#
# Cluster 4
# Number of Points: 20
# Cluster Songs:
# 6                                      Heat of the Summer
# 37                                            Come Around
# 135                                       Spectacular Now
# 136                                      Good Lord Lorrie
# 236                                               No Plan
# 306                                                7 Days
# 443                                     MIA (feat. Kap G)
# 477                                               Sunrise
# 505     I'm the One (feat. Justin Bieber, Quavo, Chanc...
# 736                                             Big Dusty
# 935                                  Devil In A New Dress
# 1066                                                 Fire
# 1086                                              My Last
# 1472                                       Ain't Too Hard
# 1590                       Be Together (feat. Wild Belle)
# 1777                                    Suraj Hua Maddham
# 1834                                        Crooked Smile
# 1835                                         Let Nas Down
# 2020                                        Drop the Game
# 2021                                       Tuscan Leather
# Name: name, dtype: object
#
# Cluster 5
# Number of Points: 231
# Cluster Songs:
# 8                                   Push My Luck
# 40                                       October
# 44                               Ready To Let Go
# 79                                           Roo
# 87      She'd Say (with Ladysmith Black Mambazo)
#                           ...
# 2071                          Where Do We Go Now
# 2075             All About It (feat. Ed Sheeran)
# 2087                                  Wanderlust
# 2102       House Of Balloons / Glass Table Girls
# 2146              White Lies (feat. Jenni Potts)
# Name: name, Length: 231, dtype: object
#
# Cluster 6
# Number of Points: 485
# Cluster Songs:
# 18                         Paint Me a Birmingham
# 22                                  Luckiest Man
# 29                                     Losing Me
# 30                                    Trampoline
# 36                                  Saint-Tropez
#                           ...
# 2129                                     Sandman
# 2138                                     I.Crawl
# 2141    III. Telegraph Ave. ("Oakland" by Lloyd)
# 2145                                       Bloom
# 2153                           Echoes (feat. Py)
# Name: name, Length: 485, dtype: object
#
# Cluster 9
# Number of Points: 21
# Cluster Songs:
# 23                                                Trouble
# 72                       We Gon Make It (feat. Meek Mill)
# 116     Swivel (with EARTHGANG) - From The Upcoming Al...
# 251                                            Hard To Do
# 262                                   Webbie (feat. Duke)
# 264                                  Woke Up in Nashville
# 316                            The Man Who Has Everything
# 429                                               Elevate
# 575                                             Fuk Faces
# 633       Nothing But The Best - Remastered Album Version
# 773                                              chirpin'
# 788                              In Tune (& Metro Boomin)
# 987                                                  4 AM
# 1153                                        Party Monster
# 1154                                          True Colors
# 1185                                          Wavin' Flag
# 1326                                   Backseat Freestyle
# 2086                                             Live For
# 2099                                             The Fall
# 2133                                        All The Shine
# 2152                                             Kusanagi
# Name: name, dtype: object
#
# Cluster 11
# Number of Points: 15
# Cluster Songs:
# 81                    Do You Remember
# 103     Werewolf (feat. Yoshi Flower)
# 357        rockstar (feat. 21 Savage)
# 415                         Worldwide
# 431                     Space for Two
# 580                             Hello
# 909                            Say A'
# 1148                         Reminder
# 1343                       Stick Talk
# 1592                          Trouble
# 1756                       Make Light
# 1810                    Higher Ground
# 1897                          All Say
# 1906                       Successful
# 1916                  Never Say Never
# Name: name, dtype: object
#
# Cluster 16
# Number of Points: 38
# Cluster Songs:
# 132                                        ocean eyes
# 182                                              Hell
# 244                                Wake Up in the Sky
# 261            Nights Like This (feat. Ty Dolla $ign)
# 271                                      Lose You Too
# 281                                        The Reaper
# 294                                       No Promises
# 381                                              Mess
# 409                                      Flying Kites
# 549                                        White Sand
# 569                           Too Gone (feat. Khalid)
# 655                                   Crown the Kings
# 714                                         Your Side
# 779                                           Hellcat
# 809     Family Don't Matter (feat. Millie Go Lightly)
# 822                           I Told You/ Another One
# 829                                     All The Girls
# 852                                      I Fall Apart
# 868                                        Group Home
# 894                                      Cowboy Boots
# 1070                                     World Ablaze
# 1072                                        Switch Up
# 1162       My Boys (feat. Ralo, Trouble and Lil Durk)
# 1220                                       Inside Out
# 1237                                  Never Satisfied
# 1283                                      Wagon Wheel
# 1307                                 Stay for a While
# 1339                                       Amansworld
# 1346                               Blood On the Money
# 1352                                    Ain't No Time
# 1356                                         Low Life
# 1441                               Crash (feat. Pell)
# 1445                                         Out Late
# 1527                                         I Was Me
# 1662                      Hyperparadise - Flume Remix
# 1716              Aaja Sajan Aaja (From "Khal Nayak")
# 1846                                     Fitzpleasure
# 2127                                             Volt
# Name: name, dtype: object
#
# Cluster 17
# Number of Points: 11
# Cluster Songs:
# 61             Rooting For You
# 190                      Karma
# 343                 SICKO MODE
# 777              Mediterranean
# 869              Killed Before
# 911            Everybody Talks
# 1369       Angels (feat. Saba)
# 1872              Up All Night
# 1875             Unforgettable
# 2043    This House Is a Circus
# 2074    Won't Mind (feat. MAX)
# Name: name, dtype: object
#
# Cluster 22
# Number of Points: 40
# Cluster Songs:
# 368                                              Dedicate
# 372                      Mona Lisa (feat. Kendrick Lamar)
# 485                                       What You Wanted
# 508                                            Good Grief
# 524                                            1942 Flows
# 532                                          Takin' Shots
# 602                                            Fresh Eyes
# 692                                      Heaven In Hiding
# 728                                           Bad At Love
# 780                                         Love Lockdown
# 864                                                 Sunny
# 933                                                Angels
# 1057                                            Blessings
# 1115                                    Bankrolls On Deck
# 1131                                    Calling Your Name
# 1233                                           Look Alive
# 1331                                            The Sound
# 1337                                                  Top
# 1384                        Never Be Like You (feat. Kai)
# 1427                                           Redemption
# 1474    Jam (feat. Trey Songz, Ty Dolla $ign and Jamie...
# 1481                                                 Here
# 1482                                        Really Really
# 1521                              Recognize (feat. Drake)
# 1629                     Earned It (Fifty Shades Of Grey)
# 1646                                Eve II (Odesza Remix)
# 1659                                                Latch
# 1738                                      Maston Ka Jhund
# 1757                                         Carried Away
# 1793                                                 Rely
# 1795                         If You Don't (feat. Cumulus)
# 1804                                         Oxford Comma
# 1958                                             Flawless
# 1965                                           Funky Town
# 1966    Earned It (Fifty Shades Of Grey) - From The "F...
# 1994                                       Counting Stars
# 2030                                         The Language
# 2035                                               All Me
# 2105                                          Coming Down
# 2134                                            Heartbeat
# Name: name, dtype: object
#
# Noise Cluster

# %%
output_data = raw_data.copy()
output_data = output_data[['song_uri', 'name']]
output_data['cluster'] = labels
output_data = output_data[output_data.cluster.isin(playlist_clusters)]
print(output_data.shape)
# Out:
# (1295, 3)

# %%
print(output_data.head())
# Out:
#                  song_uri                name  cluster
# 0  3TMUdD9vE4DoqDYi7VXStt         Fool's Gold        0
# 2  0CJvDUBeEL1Rmpx7MH28CQ             For You        1
# 3  3GRSqlALWISqLeNncZMbpX             Mean It        1
# 6  649o53ULWYN1y7V2OI5kgo  Heat of the Summer        3
# 8  2a3dopgTF1q4rMVDJ1rwBU        Push My Luck        4

# %%
output_data.to_csv('clustered_data.csv')
